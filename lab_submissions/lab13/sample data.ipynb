# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.jet()

import sklearn.datasets as datasets

# %%
chosencenters = [[1,1],[-0.5,0],[1,-1]]
cc = np.asarray(chosencenters)

# %%
X, Y = datasets.make_blobs(centers=3, cluster_std=(.5,.5), random_state=0)

#X,Y = datasets.make_blobs(centers = chosencenters, cluster_std=(.5,.5))

plt.scatter(cc[:,0],cc[:,1],s=100,c='black')

plt.scatter(X[:,0],X[:,1],c=Y)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(3, random_state=8)
Y_hat = kmeans.fit(X).labels_

Y_hat
# Out:
# array([0, 0, 0, 2, 0, 2, 1, 1, 1, 2, 2, 1, 0, 0, 1, 0, 1, 0, 0, 1, 2, 2, 2,
#        0, 2, 0, 1, 1, 2, 0, 0, 0, 0, 2, 1, 2, 0, 1, 0, 0, 0, 1, 1, 1, 2, 2,
#        1, 0, 2, 1, 2, 2, 0, 1, 1, 2, 1, 0, 0, 2, 2, 2, 2, 1, 1, 1, 1, 0, 1,
#        0, 2, 0, 1, 0, 2, 2, 2, 2, 2, 0, 1, 1, 1, 1, 0, 0, 0, 2, 2, 0, 1, 1,
#        2, 2, 0, 0, 2, 1, 1, 1])

# %%
plt.scatter(X[:,0],X[:,1],c=Y_hat)

# %%
plt.scatter(X[:,0], X[:,1], c=Y_hat, alpha=0.4)
mu = kmeans.cluster_centers_
plt.scatter(mu[:,0], mu[:,1], s=100, c='black')
#print mu

# %%
mu
# Out:
# array([[ 0.92805351,  1.0329738 ],
#        [ 1.06037021, -0.98988788],
#        [-0.54190676,  0.11680514]])
